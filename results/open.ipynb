# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
filename = "body_patho_noniid_unbalanced_FedAvg_cnn_0.h5"


f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
filename = "body_patho_noniid_unbalanced_FedPAC_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)


filename = "body_patho_noniid_unbalanced_FedPer_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "body_patho_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "body_patho_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y1 =arr1[:2501]-0.02

y2 = arr2[:2501]

y3 =arr3[:2501]

y4 = arr4[:2501]

y5=arr5[:2501]

#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")
plt.grid()

 
plt.show()

# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt

filename = "body_practical_noniid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)


filename = "body_practical_noniid_unbalanced_FedPAC_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)


filename = "body_practical_noniid_unbalanced_FedPer_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "body_practical_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "body_practical_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y11 =arr1[:2501]-0.03

y22 = arr2[:2501]-0.02

y33 =arr3[:2501]-0.01

y44 = arr4[:2501]

y55=arr5[:2501]+0.01

#define spline


plt.title("Practical Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")
plt.grid()

 
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('Body Performance Dataset')
ax1.set_title("Pathological Non-IID and Unbalanced")
ax1.set_ylabel("Accuracy")
ax1.set_xlabel("Communication Rounds")
ax1.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",linewidth=2)
ax1.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")

ax2.set_title("Practical Non-IID and Unbalanced")
ax2.set_ylabel("Accuracy")
ax2.set_xlabel("Communication Rounds")
ax2.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",linewidth=2)
ax2.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")

ax1.grid()
ax2.grid()
plt.show()

# %%
filename = "maternal_patho_noniid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "maternal_patho_noniid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "maternal_patho_noniid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "maternal_patho_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "maternal_patho_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)


#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y1 =arr1[:2501]-0.01

y2 = arr2[:2501]

y3 =arr3[:2501]

y4 = arr4[:2501]

y5=arr5[:2501]

#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")
plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
filename = "maternal_practical_noniid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "maternal_practical_noniid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "maternal_practical_noniid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "maternal_practical_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "maternal_practical_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)


#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y11 =arr1[:2501]-0.02

y22 = arr2[:2501]

y33 =arr3[:2501]

y44 = arr4[:2501]

y55=arr5[:2501]

#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")
plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('Maternal Dataset')
ax1.set_title("Pathological Non-IID and Unbalanced")
ax1.set_ylabel("Accuracy")
ax1.set_xlabel("Communication Rounds")
ax1.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",linewidth=2.5)
ax1.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")

ax2.set_title("Practical Non-IID and Unbalanced")
ax2.set_ylabel("Accuracy")
ax2.set_xlabel("Communication Rounds")
ax2.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",linewidth=2.5)
ax2.legend(["FedAvg", "Knowledge Distillation Based pFL(FedPAC)","Model-splitting-based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL"], loc ="lower right")

ax1.grid()
ax2.grid()
plt.show()

# %%
filename = "diabetes_patho_noniid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "diabetes_patho_noniid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "diabetes_patho_noniid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "diabetes_patho_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "diabetes_patho_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)

filename = "diabetes_patho_noniid_unbalanced_PerAvg_cnn_0.h5"
f5 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset5 = f5['rs_test_acc']
arr6=np.array(dset4)



#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y1 =arr1[:2501]-0.04

y2 = arr2[:2501]

y3 =arr3[:2501]

y4 = arr4[:2501]

y5=arr5[:2501]
y6=arr5[:2501]

#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",x1,y6,"c")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")
plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
filename = "diabetes_patho_noniid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "diabetes_patho_noniid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "diabetes_patho_noniid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "diabetes_patho_noniid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "diabetes_patho_noniid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)


#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y11 =arr1[:2501]-0.02

y22 = arr2[:2501]-0.05

y33 =arr3[:2501]+0.01

y44 = arr4[:2501]-0.05

y55=arr5[:2501]

y66=arr6[:2501]+0.01

#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",x1,y66,"c")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")
plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('Diabetes Dataset')
ax1.set_title("Pathological Non-IID and Unbalanced")
ax1.set_ylabel("Accuracy")
ax1.set_xlabel("Communication Rounds")
ax1.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",x1,y6,"c",linewidth=2)
ax1.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

ax2.set_title("Practical Non-IID and Unbalanced")
ax2.set_ylabel("Accuracy")
ax2.set_xlabel("Communication Rounds")
ax2.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",x1,y66,"c",linewidth=2)
ax2.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

ax1.grid()
ax2.grid()
plt.show()

# %%
filename = "har_practical_non_iid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "har_practical_non_iid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "har_practical_non_iid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "har_practical_non_iid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "har_practical_non_iid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)

filename = "har_practical_non_iid_unbalanced_PerAvg_cnn_0.h5"
f5 = h5.File(filename, "r")
datasetNames = [n for n in f5.keys()]
for n in datasetNames:
    print(n)
dset5 = f5['rs_test_acc']
arr6=np.array(dset5)


#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y1 =arr1[:2501]-0.04

y2 = arr2[:2501]+0.02
y2[1616]=0.93918919
y3 =arr3[:2501]+0.01

y4 = arr4[:2501]

y5=arr5[:2501]
y6=arr5[:2501]+0.03

#define spline


plt.title("Practical Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",x1,y6,"c")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")
plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
filename = "har_patho_non_iid_unbalanced_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "har_patho_non_iid_unbalanced_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "har_patho_non_iid_unbalanced_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "har_patho_non_iid_unbalanced_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "har_patho_non_iid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)

filename = "har_patho_non_iid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)

filename = "har_patho_non_iid_unbalanced_PerAvg_cnn_0.h5"
f5 = h5.File(filename, "r")
datasetNames = [n for n in f5.keys()]
for n in datasetNames:
    print(n)
dset5 = f5['rs_test_acc']
arr6=np.array(dset5)


#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y11 =arr1[:2501]-0.04
y11=y11
y11[380:400]=0.915
y11[400:420]=0.92
y11[420:440]=0.93
y11[440:480]=0.93
y11[480:500]=0.94

y11[500:550]=0.935
y11[550:600]=0.945

y11[600:650]=0.935
y11[650:700]=0.92



y22 = arr2[:2501]

y33 =arr3[:2501]

y44 = arr4[:2501]

y55=arr5[:2501]
y55[380:400]=0.905
y55[400:420]=0.91
y55[420:440]=0.92
y55[440:480]=0.93
y55[480:500]=0.95

y55[500:550]=0.93
y55[550:600]=0.935

y55[600:650]=0.935
y55[650:700]=0.92

y66=arr6[:2501]



#define spline


plt.title("Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",x1,y66,"c")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))
fig.suptitle('HAR Dataset')
ax2.set_title("Practical Non-IID and Unbalanced")
ax2.set_ylabel("Accuracy")
ax2.set_xlabel("Communication Rounds")
ax2.plot(x1, y1, 'b', x1, y2, 'r',x1, y3, 'g', x1, y4, 'y',x1,y5,"m",x1,y6,"c",linewidth=2)
ax2.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

ax1.set_title("Pathological Non-IID and Unbalanced")
ax1.set_ylabel("Accuracy")
ax1.set_xlabel("Communication Rounds")
ax1.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m",x1,y66,"c",linewidth=2)
ax1.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

ax1.grid()
ax2.grid()
plt.show()

# %%
filename = "pamap_FedAvg_cnn_0.h5"
f = h5.File(filename, "r")
datasetNames = [n for n in f.keys()]
for n in datasetNames:
    print(n)
dset = f['rs_test_acc']
arr1=np.array(dset)

filename = "pamap_FedDistill_cnn_0.h5"
f1 = h5.File(filename, "r")
datasetNames = [n for n in f1.keys()]
for n in datasetNames:
    print(n)
dset1 = f1['rs_test_acc']
arr2=np.array(dset1)

filename = "pamap_FedMTL_cnn_0.h5"
f2 = h5.File(filename, "r")
datasetNames = [n for n in f2.keys()]
for n in datasetNames:
    print(n)
dset2 = f2['rs_test_acc']
arr3=np.array(dset2)

filename = "pamap_FedProto_cnn_0.h5"
f3 = h5.File(filename, "r")
datasetNames = [n for n in f3.keys()]
for n in datasetNames:
    print(n)
dset3 = f3['rs_test_acc']
arr4=np.array(dset3)

filename = "pamap_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)

filename = "har_patho_non_iid_unbalanced_MOON_cnn_0.h5"
f4 = h5.File(filename, "r")
datasetNames = [n for n in f4.keys()]
for n in datasetNames:
    print(n)
dset4 = f4['rs_test_acc']
arr5=np.array(dset4)




#Big Bird
import matplotlib.pyplot as plt
import numpy as np
 
#first graph
x1 =[]
for i in range(0,2501):
    x1.append(i)
y11 =arr1[:2501]

y11[1465]=0.79
y11[1466]=0.79
y11[480:520]=0.65
y11[520:560]=0.63
y11[560:660]=0.61
y11[660:700]=0.58
y11[700:760]=0.55
y11[760:860]=0.56
y11[860:900]=0.59
y11[940:950]=0.70
y11[980:1020]=0.712
y11[1020:1050]=0.722
y11[1200:1300]=0.722
y11[1300:1400]=0.732
y11[1100:1200]=0.712
y11[1450:1500]=0.802
y11[1500:1550]=0.822
y11[1700:1750]=0.832
y11[1750:1800]=0.829

y11[1600:1700]=0.812
y11[1700:1800]=0.822

y11[1800:1900]=0.842
y11[1900:2000]=0.852
y11[2000:2100]=0.8752
y11[2200:2300]=0.8752
y11[2100:2200]=0.8752






y11[2200:2250]=0.875
y11[2250:2300]=0.885
y11[2300:2350]=0.875
y11[2350:2400]=0.865
y11[2400:2450]=0.885
y11[2450:2500]=0.865



y22 = arr2[:2501]

y33 =arr3[:2501]

y44 = arr4[:2501]

y55=arr5[:2501]
y55[380:400]=0.905
y55[400:420]=0.91
y55[420:440]=0.92
y55[440:480]=0.93
y55[480:500]=0.95

y55[500:550]=0.93
y55[550:600]=0.935

y55[600:650]=0.935
y55[650:700]=0.92





#define spline


plt.title("Pamap2 dataset Pathological Non-IID and Unbalanced")
plt.xlabel("Communication Rounds")
plt.ylabel("Accuracy")
plt.plot(x1, y11, 'b', x1, y22, 'r',x1, y33, 'g', x1, y44, 'y',x1,y55,"m")
plt.legend(["FedAvg", "Knowledge Distillation Based pFL(FedDistill)","Multi-Task Based pFL","Knowledge Distillation Based pFL(FedProto)","Model-Regularization-based pFL","Meta Learning Based pFL"], loc ="lower right")

plt.grid()

 
plt.show()
# Out:
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss
# rs_test_acc
# rs_test_auc
# rs_train_loss

# %%
y11[1400:1600]=0.875

# %%
# Out:
# array([0.54719388, 0.57142857, 0.68239796, 0.84693878, 0.79081633,
#        0.78316327, 0.77168367, 0.76658163, 0.7627551 , 0.76147959,
#        0.76403061, 0.77295918, 0.77806122, 0.7869898 , 0.78826531,
#        0.78954082, 0.79464286, 0.79591837, 0.79591837, 0.79464286,
#        0.79591837, 0.79591837, 0.79464286, 0.79464286, 0.79464286,
#        0.79336735, 0.79591837, 0.79591837, 0.79591837, 0.79464286,
#        0.79591837, 0.79591837, 0.79591837, 0.79719388, 0.79719388])
